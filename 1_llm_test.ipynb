# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '어떤 분야를 찾으시는지 알려주시면 더 정확히 추천해드릴게요. (예: 웹개발, 데이터사이언스, 클라우드, 모바일, 디자인, 취업 대비, 알고리즘 등)\n\n우선 전반적인 안내 드릴게요.\n\n- 인프런에 있는 주요 카테고리\n  - 개발: 프론트엔드(HTML/CSS/JavaScript, React, Vue), 백엔드(Node.js, Django, Spring), 모바일(Android/iOS/Flutter), 게임 개발\n  - 데이터: Python, 데이터분석, 머신러닝, 딥러닝, 데이터 엔지니어링\n  - 클라우드/인프라: AWS/GCP/Azure, Docker, Kubernetes, CI/CD\n  - 알고리즘/코딩테스트: 자료구조, 알고리즘 문제 풀이, 실전 코테 대비\n  - 디자인/UX: UI디자인, Figma, 프로토타이핑\n  - 경영·마케팅·기획: 제품기획, 디지털마케팅, 스타트업 실무\n  - 자격증/회계/외국어/자기계발 등 실무·취업 관련 강의도 다수\n\n- 인기 강의 유형 및 선택 팁\n  - 입문자용 기초 강의 → 개념 + 실습 프로젝트 포함 여부 확인\n  - 실무자용 실전 프로젝트/포폴 중심 강의 선호\n  - 최신 기술(예: 최신 React 버전, MLOps 등)은 업데이트 날짜와 강의 노트 확인\n  - 평점·수강평·강의 데모 영상(미리보기) 확인\n  - 무료 강의나 할인(세일/번들) 활용\n\n- 강의 검색 방법\n  - 인프런 사이트에서 키워드 검색 / 카테고리 필터 / 난이도·가격·평점 필터 사용\n  - 커리큘럼(강의목차)과 수강후기, 제공 소스(깃허브) 확인\n\n원하시면\n1) 관심 분야와 현재 수준(초급/중급/고급) 알려주시면 추천 강의 리스트(무료 포함) 만들어 드리거나  \n2) 특정 목표(취업, 자격증, 포트폴리오 등)를 알려주시면 맞춤 추천 드릴게요.'
